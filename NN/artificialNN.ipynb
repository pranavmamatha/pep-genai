# %% [markdown]
# Install the Requirements

# %%
! pip3 install torch torchvision
# Out:
# Requirement already satisfied: torch in D:\CscamRepo\RepoScam\LPU-GenAi\.venv\Lib\site-packages (2.12.1)
# Collecting torchvision
#   Using cached torchvision-0.27.1-cp314-cp314-win_amd64.whl.metadata (5.5 kB)
# Requirement already satisfied: filelock in D:\CscamRepo\RepoScam\LPU-GenAi\.venv\Lib\site-packages (from torch) (3.29.4)
# Requirement already satisfied: typing-extensions>=4.10.0 in D:\CscamRepo\RepoScam\LPU-GenAi\.venv\Lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools<82 in D:\CscamRepo\RepoScam\LPU-GenAi\.venv\Lib\site-packages (from torch) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in D:\CscamRepo\RepoScam\LPU-GenAi\.venv\Lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in D:\CscamRepo\RepoScam\LPU-GenAi\.venv\Lib\site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in D:\CscamRepo\RepoScam\LPU-GenAi\.venv\Lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in D:\CscamRepo\RepoScam\LPU-GenAi\.venv\Lib\site-packages (from torch) (2026.6.0)
# Requirement already satisfied: numpy in D:\CscamRepo\RepoScam\LPU-GenAi\.venv\Lib\site-packages (from torchvision) (2.5.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in D:\CscamRepo\RepoScam\LPU-GenAi\.venv\Lib\site-packages (from torchvision) (12.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in D:\CscamRepo\RepoScam\LPU-GenAi\.venv\Lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in D:\CscamRepo\RepoScam\LPU-GenAi\.venv\Lib\site-packages (from jinja2->torch) (3.0.3)
# Using cached torchvision-0.27.1-cp314-cp314-win_amd64.whl (4.2 MB)
# Installing collected packages: torchvision
# Successfully installed torchvision-0.27.1

# %%
##import the necessary libraries
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

# %%
#1. Data Preparation
#Transforms convert images to pytorch Tensors and normalize pixels to the range [0, 1]
transform = transforms.Compose([transforms.ToTensor()])

train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
test_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

train_loader = DataLoader(dataset=train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(dataset=test_dataset, batch_size=64, shuffle=False)
# Out:
# 100.0%
# 100.0%
# 100.0%
# 100.0%

# %%
#2. Define the Artificial Neural Network Model
class NeuralNetwork(nn.Module):
    def _init_(self):
        super(NeuralNetwork, self)._init_()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(28*28, 512),
            nn.ReLU(),
            nn.Linear(512, 512),
            nn.ReLU(),
            nn.Linear(512, 10)
        )
    def forward(self, x):
        x = self.flattern(x)
        logits = self.linear_relu_stack(x)
        return logits

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
model = NeuralNetwork().to(device)
# Out:
# Using device: cpu
